# %%
import torch
import numpy as np

img = np.array([[[0,0,1], [0,1,0], [1,0,0]]])
img_tensor = torch.tensor(img, dtype=float)

# %%
img_tensor.view(-1)
# Out:
# tensor([0., 0., 1., 0., 1., 0., 1., 0., 0.], dtype=torch.float64)

# %%
img_tensor.permute(1,2,0).shape
# Out:
# torch.Size([3, 3, 1])

# %%
img_tensor.permute(1,2,0).reshape(-1,3).shape
# Out:
# torch.Size([3, 3])
