# %%
# 나눔고딕 폰트 설치
# !apt-get update -qq
# !apt-get install -y fonts-nanum


# Matplotlib 폰트 설정
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib


# 나눔고딕 폰트 경로 설정
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
font_manager.fontManager.addfont(font_path)
rc('font', family='NanumGothic', size=12)
# 런타임 다시 시작할 필요 X

# 마이너스 폰트 깨짐 방지
matplotlib.rcParams['axes.unicode_minus'] = False


print("폰트 설정 완료 - NanumGothic 적용됨")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# 폰트 설정 완료 - NanumGothic 적용됨

# %%
import numpy as np

# 배열 생성
arr = np.array([1,2,3,4,5])
print(arr)
print(arr.dtype)    # 데이터 타입
# Out:
# [1 2 3 4 5]
# int64

# %%
# dtype 지정
#  (경량화 시 float -> int로 많이 바꾼다.)
np.array([1,2,3], dtype=np.float32)
# Out:
# array([1., 2., 3.], dtype=float32)

# %%
# 브로드캐스팅 연습
arr1 = np.array([1,2,3])
arr2 = np.array([[10], [20], [30]])

print(arr1)
print(arr2)
print()

print(arr1.shape)
print(arr2.shape)
# Out:
# [1 2 3]
# [[10]
#  [20]
#  [30]]
#
# (3,)
# (3, 1)

# %%
result = arr1 + arr2
print(result)
# Out:
# [[11 12 13]
#  [21 22 23]
#  [31 32 33]]

# %%
result.shape
# Out:
# (3, 3)

# %%
# 집계함수 / axis 개념
# 집계함수

matrix = np.array([[1,2,3],[4,5,6]])
print(matrix)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print("전체 합:", np.sum(matrix))
# Out:
# 전체 합: 21

# %%
print('열 기준 합(axis=0):', np.sum(matrix, axis=0))  # 세로방향 (서로 다른 행 끼리)
print('행 기준 합(axis=1):', np.sum(matrix, axis=1))  # 가로방향 (서로 다른 열 끼리)
# Out:
# 열 기준 합(axis=0): [5 7 9]
# 행 기준 합(axis=1): [ 6 15]

# %%
print('열 기준 평균(axis=0):', np.mean(matrix, axis=0))
print('행 기준 평균(axis=1):', np.mean(matrix, axis=1))
# Out:
# 열 기준 평균(axis=0): [2.5 3.5 4.5]
# 행 기준 평균(axis=1): [2. 5.]

# %%
# 조건 인덱싱

data = np.array([3, 8, 1, 6, 2, 9])

data[data > 5]  # True 인 값만 필터링
# Out:
# array([8, 6, 9])

# %%
# matplotlib plot 기본 사용법
# 기본 Plot 실습
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 10, 100)
y = np.sin(x)


plt.plot(x, y, label="Sine 함수")
plt.title("기본 선 그래프 (Line Plot)")
plt.xlabel("X 축")
plt.ylabel("Y 축")
plt.legend()
plt.show()

# %%
# Scatter Plot 실습
plt.scatter(x, y, label="Sin 데이터 포인트")
plt.title("Scatter Plot 예제")
plt.xlabel("X 축")
plt.ylabel("Y 축")
plt.legend()
plt.show()

# %%
# 실습 과제: 두 개의 함수를 하나의 그래프에 시각화하기


x = np.linspace(-5, 5, 200)
y1 = x            # 1차 함수
y2 = x ** 2       # 2차 함수


plt.plot(x, y1, label="y = x")
plt.plot(x, y2, label="y = x^2")
plt.title("1차 함수와 2차 함수 비교")
plt.xlabel("X 축")
plt.ylabel("Y 축")
plt.legend()
plt.grid(True)
plt.show()

# %%
# eos
