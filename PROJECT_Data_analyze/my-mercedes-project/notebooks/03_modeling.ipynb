# %% [markdown]
# # 모델 학습 및 제출 파일 생성용

# %% [markdown]
# - data/processed/train_clean.csv 불러오기
#
# - 데이터를 Train/Validation으로 쪼개기
#
# - XGBoost, LightGBM 같은 모델 학습시키기
#
# - 교차 검증(Cross-Validation) 점수 확인 후 최종 submission.csv 파일 뽑아내기
