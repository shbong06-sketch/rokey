# %% [markdown]
# # 전처리 및 피처 엔지니어링 실험용

# %% [markdown]
# - 문자열로 된 범주형 변수를 숫자로 바꾸기 (LabelEncoder)
#
# - 벤츠 대회의 핵심 치트키였던 PCA, ICA를 사용해 차원 축소 데이터 결합하기
#
# - 결과물: 전처리가 완료된 깔끔한 데이터를 data/processed/train_clean.csv 같은 파일로 저장
