# %%
# !ros2 service call /robot/command patrol_interfaces/srv/Command "{order: 'A-1'}"
# Out:
# waiting for service to become available...
# requester: making request: patrol_interfaces.srv.Command_Request(order='A-1')
#
# response:
# patrol_interfaces.srv.Command_Response(accepted=True)

# %%
# !ros2 action send_goal /robot/patrol patrol_interfaces/action/Patrol "{laps: 5}" --feedback
# Out:
# Waiting for an action server to become available...
# Sending goal:
#      laps: 5
#
# Goal accepted with ID: c623f8607505468e8e94060f3d63a436
#
# Feedback:
#     progress: 1
#
# Feedback:
#     progress: 2
#
# Feedback:
#     progress: 3
#
# Feedback:
#     progress: 4
#
# Feedback:
#     progress: 5
#
# Result:
#     done: true
#
# Goal finished with status: SUCCEEDED
